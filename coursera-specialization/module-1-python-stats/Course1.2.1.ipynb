# %% [markdown]
# # Pandas important points to note
#
# ##### How does Pandas help ?
# -  Series: A one dimensional array like object that can hold data of any type. It is similar to a colum or rown in a table
# - DataFrame: A two dimensional tabular data structure with labeled axes (rows and columns) .
# Al.

# %% [markdown]
# ## Pandas DataFrame

# %% [raw]
# "first_name":["Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
# "last_name':['Miller', 'Jacobson', ".",'Miller', 'Jacobson'],
# "age": [42, 52, 36, 24, 73],
# "preTestScore":(4, 24, 31,".", "."],
# "postTestScore":[*25,000","94,000", 57, 62, 70]

# %%
import pandas as pd
import numpy as np

# %%
raw_data={"first_name":['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
"last_name":['Miller', 'Jacobson', ".",'Miller', 'Jacobson'],
"age": [42, 52, 36, 24, 73],
"preTestScore":[4, 24, 31,".", "."],
"postTestScore":["25,000","94,000", 57, 62, 70]}
df=pd.DataFrame(raw_data,columns=["first_name","last_name","age","preTestScore","postTestScore"])
print(df)
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Miller   24            .            62
# 4        Amy  Jacobson   73            .            70

# %%
df.shape
# Out:
# (5, 5)

# %%
list(df.columns)
# Out:
# ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     5 non-null      object
#  1   last_name      5 non-null      object
#  2   age            5 non-null      int64
#  3   preTestScore   5 non-null      object
#  4   postTestScore  5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes

# %% [markdown]
# Save the dataframe into a csv file as example .csv

# %%
df.to_csv("example.csv",index=False)

# %% [markdown]
# Reading csv file

# %%
df1=pd.read_csv("example.csv")
df1.head()
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Miller   24            .            62
# 4        Amy  Jacobson   73            .            70

# %%
df2=pd.read_csv("example.csv", header=None)
df2.head()
# Out:
#             0          1    2             3              4
# 0  first_name  last_name  age  preTestScore  postTestScore
# 1       Jason     Miller   42             4         25,000
# 2       Molly   Jacobson   52            24         94,000
# 3        Tina          .   36            31             57
# 4        Jake     Miller   24             .             62

# %%
df3=pd.read_csv("example.csv", nrows=3)
df3.head()
# Out:
#   first_name last_name  age  preTestScore postTestScore
# 0      Jason    Miller   42             4        25,000
# 1      Molly  Jacobson   52            24        94,000
# 2       Tina         .   36            31            57

# %% [markdown]
# For documentation

# %%
# ?pd.read_csv
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
df.head(2)
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000

# %%
df1.tail(2)
# Out:
#   first_name last_name  age preTestScore postTestScore
# 3       Jake    Miller   24            .            62
# 4        Amy  Jacobson   73            .            70

# %% [markdown]
# # Acces specific row or specific column or specific cell

# %%
df1
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Miller   24            .            62
# 4        Amy  Jacobson   73            .            70

# %%
# Accessing a row by row label
df.loc[2,:]
# Out:
# first_name       Tina
# last_name           .
# age                36
# preTestScore       31
# postTestScore      57
# Name: 2, dtype: object

# %%
# Accessing a column by row label
df1.loc[:,["last_name","preTestScore"]]
# Out:
#   last_name preTestScore
# 0    Miller            4
# 1  Jacobson           24
# 2         .           31
# 3    Miller            .
# 4  Jacobson            .

# %%
df1[["last_name","preTestScore"]]
# Out:
#   last_name preTestScore
# 0    Miller            4
# 1  Jacobson           24
# 2         .           31
# 3    Miller            .
# 4  Jacobson            .

# %%
# Accessing specific cell
df1.loc[2,["last_name"]]
# Out:
# last_name    .
# Name: 2, dtype: object

# %% [markdown]
# # Row indexes are labels

# %%
df1
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Miller   24            .            62
# 4        Amy  Jacobson   73            .            70

# %% [markdown]
# Read the example.csv and make the index colums as "First Name" and "Last name"

# %%
df4=df1.set_index(["first_name","last_name"])
df4
# Out:
#                       age preTestScore postTestScore
# first_name last_name
# Jason      Miller      42            4        25,000
# Molly      Jacobson    52           24        94,000
# Tina       .           36           31            57
# Jake       Miller      24            .            62
# Amy        Jacobson    73            .            70

# %%
df4.iloc[2,:]
# Out:
# age              36
# preTestScore     31
# postTestScore    57
# Name: (Tina, .), dtype: object

# %%
df1.describe()
# Out:
#              age
# count   5.000000
# mean   45.400000
# std    18.460769
# min    24.000000
# 25%    36.000000
# 50%    42.000000
# 75%    52.000000
# max    73.000000

# %%
df5=pd.read_csv("example.csv", thousands=',')
df5
# Out:
#   first_name last_name  age preTestScore  postTestScore
# 0      Jason    Miller   42            4          25000
# 1      Molly  Jacobson   52           24          94000
# 2       Tina         .   36           31             57
# 3       Jake    Miller   24            .             62
# 4        Amy  Jacobson   73            .             70
